# %%
from manim.utils.ipython_magic import ManimMagic

# %%
# %register_line_cell_magic ManimMagic
# Out:
# UsageError: Line magic function `%register_line_cell_magic` not found.

# %%
import IPython
IPython.__version__
# Out:
# '9.9.0'

# %%
get_ipython()

# %%
# !pip install "manim[jupyter]"
# Out:
# ...
# WARNING: manim 0.19.1 does not provide the extra 'jupyter'
